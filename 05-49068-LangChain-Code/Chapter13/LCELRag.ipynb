# %%
#导入需要的依赖包
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
# Requires:
# pip install langchain docarray tiktoken
from langchain_community.vectorstores import DocArrayInMemorySearch
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableParallel, RunnablePassthrough
from langchain_openai import OpenAIEmbeddings
from langchain_community.chat_models import ChatOllama
#配置模型信息
model = ChatOllama(model="qwen3:1.7b")

# %%
vectorstore = DocArrayInMemorySearch.from_texts(
    ["harrison worked at kensho", "bears like to eat honey"],
    embedding=OpenAIEmbeddings(),
)
retriever = vectorstore.as_retriever()

template = """Answer the question based only on the following context:
{context}

Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template)
output_parser = StrOutputParser()

setup_and_retrieval = RunnableParallel(
    {"context": retriever, "question": RunnablePassthrough()}
)
chain = setup_and_retrieval | prompt | model | output_parser

chain.invoke("where did harrison work?")
# Out:
# G:\Program Files\anaconda3\Lib\site-packages\pydantic\_migration.py:283: UserWarning: `pydantic.error_wrappers:ValidationError` has been moved to `pydantic:ValidationError`.
#   warnings.warn(f'`{import_path}` has been moved to `{new_location}`.')
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_backends\sync.py:100, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#      99 with map_exceptions(exc_map):
# --> 100     sock = socket.create_connection(
#     101         address,
#     102         timeout,
#     103         source_address=source_address,
#     104     )
#     105     for option in socket_options:
#
# File G:\Program Files\anaconda3\Lib\socket.py:851, in create_connection(address, timeout, source_address, all_errors)
#     850 if not all_errors:
# --> 851     raise exceptions[0]
#     852 raise ExceptionGroup("create_connection failed", exceptions)
#
# File G:\Program Files\anaconda3\Lib\socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_transports\default.py:60, in map_httpcore_exceptions()
#      59 try:
# ---> 60     yield
#      61 except Exception as exc:  # noqa: PIE-786
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_transports\default.py:218, in HTTPTransport.handle_request(self, request)
#     217 with map_httpcore_exceptions():
# --> 218     resp = self._pool.handle_request(req)
#     220 assert isinstance(resp.stream, typing.Iterable)
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py:262, in ConnectionPool.handle_request(self, request)
#     261         self.response_closed(status)
# --> 262     raise exc
#     263 else:
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py:245, in ConnectionPool.handle_request(self, request)
#     244 try:
# --> 245     response = connection.handle_request(request)
#     246 except ConnectionNotAvailable:
#     247     # The ConnectionNotAvailable exception is a special case, that
#     248     # indicates we need to retry the request on a new connection.
#    (...)
#     252     # might end up as an HTTP/2 connection, but which actually ends
#     253     # up as HTTP/1.1.
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_sync\connection.py:92, in HTTPConnection.handle_request(self, request)
#      91         self._connect_failed = True
# ---> 92         raise exc
#      93 elif not self._connection.is_available():
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_sync\connection.py:69, in HTTPConnection.handle_request(self, request)
#      68 try:
# ---> 69     stream = self._connect(request)
#      71     ssl_object = stream.get_extra_info("ssl_object")
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_sync\connection.py:117, in HTTPConnection._connect(self, request)
#     116 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 117     stream = self._network_backend.connect_tcp(**kwargs)
#     118     trace.return_value = stream
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_backends\sync.py:99, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#      94 exc_map: ExceptionMapping = {
#      95     socket.timeout: ConnectTimeout,
#      96     OSError: ConnectError,
#      97 }
# ---> 99 with map_exceptions(exc_map):
#     100     sock = socket.create_connection(
#     101         address,
#     102         timeout,
#     103         source_address=source_address,
#     104     )
#
# File G:\Program Files\anaconda3\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File G:\Program Files\anaconda3\Lib\site-packages\openai\_base_client.py:926, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     925 try:
# --> 926     response = self._client.send(
#     927         request,
#     928         stream=stream or self._should_stream_response_body(request=request),
#     929         **kwargs,
#     930     )
#     931 except httpx.TimeoutException as err:
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_client.py:1002, in Client._send_single_request(self, request)
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_transports\default.py:217, in HTTPTransport.handle_request(self, request)
#     205 req = httpcore.Request(
#     206     method=request.method,
#     207     url=httpcore.URL(
#    (...)
#     215     extensions=request.extensions,
#     216 )
# --> 217 with map_httpcore_exceptions():
#     218     resp = self._pool.handle_request(req)
#
# File G:\Program Files\anaconda3\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_transports\default.py:77, in map_httpcore_exceptions()
#      76 message = str(exc)
# ---> 77 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_backends\sync.py:100, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#      99 with map_exceptions(exc_map):
# --> 100     sock = socket.create_connection(
#     101         address,
#     102         timeout,
#     103         source_address=source_address,
#     104     )
#     105     for option in socket_options:
#
# File G:\Program Files\anaconda3\Lib\socket.py:851, in create_connection(address, timeout, source_address, all_errors)
#     850 if not all_errors:
# --> 851     raise exceptions[0]
#     852 raise ExceptionGroup("create_connection failed", exceptions)
#
# File G:\Program Files\anaconda3\Lib\socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_transports\default.py:60, in map_httpcore_exceptions()
#      59 try:
# ---> 60     yield
#      61 except Exception as exc:  # noqa: PIE-786
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_transports\default.py:218, in HTTPTransport.handle_request(self, request)
#     217 with map_httpcore_exceptions():
# --> 218     resp = self._pool.handle_request(req)
#     220 assert isinstance(resp.stream, typing.Iterable)
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py:262, in ConnectionPool.handle_request(self, request)
#     261         self.response_closed(status)
# --> 262     raise exc
#     263 else:
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py:245, in ConnectionPool.handle_request(self, request)
#     244 try:
# --> 245     response = connection.handle_request(request)
#     246 except ConnectionNotAvailable:
#     247     # The ConnectionNotAvailable exception is a special case, that
#     248     # indicates we need to retry the request on a new connection.
#    (...)
#     252     # might end up as an HTTP/2 connection, but which actually ends
#     253     # up as HTTP/1.1.
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_sync\connection.py:92, in HTTPConnection.handle_request(self, request)
#      91         self._connect_failed = True
# ---> 92         raise exc
#      93 elif not self._connection.is_available():
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_sync\connection.py:69, in HTTPConnection.handle_request(self, request)
#      68 try:
# ---> 69     stream = self._connect(request)
#      71     ssl_object = stream.get_extra_info("ssl_object")
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_sync\connection.py:117, in HTTPConnection._connect(self, request)
#     116 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 117     stream = self._network_backend.connect_tcp(**kwargs)
#     118     trace.return_value = stream
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_backends\sync.py:99, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#      94 exc_map: ExceptionMapping = {
#      95     socket.timeout: ConnectTimeout,
#      96     OSError: ConnectError,
#      97 }
# ---> 99 with map_exceptions(exc_map):
#     100     sock = socket.create_connection(
#     101         address,
#     102         timeout,
#     103         source_address=source_address,
#     104     )
#
# File G:\Program Files\anaconda3\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File G:\Program Files\anaconda3\Lib\site-packages\openai\_base_client.py:926, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     925 try:
# --> 926     response = self._client.send(
#     927         request,
#     928         stream=stream or self._should_stream_response_body(request=request),
#     929         **kwargs,
#     930     )
#     931 except httpx.TimeoutException as err:
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_client.py:1002, in Client._send_single_request(self, request)
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_transports\default.py:217, in HTTPTransport.handle_request(self, request)
#     205 req = httpcore.Request(
#     206     method=request.method,
#     207     url=httpcore.URL(
#    (...)
#     215     extensions=request.extensions,
#     216 )
# --> 217 with map_httpcore_exceptions():
#     218     resp = self._pool.handle_request(req)
#
# File G:\Program Files\anaconda3\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_transports\default.py:77, in map_httpcore_exceptions()
#      76 message = str(exc)
# ---> 77 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_backends\sync.py:100, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#      99 with map_exceptions(exc_map):
# --> 100     sock = socket.create_connection(
#     101         address,
#     102         timeout,
#     103         source_address=source_address,
#     104     )
#     105     for option in socket_options:
#
# File G:\Program Files\anaconda3\Lib\socket.py:851, in create_connection(address, timeout, source_address, all_errors)
#     850 if not all_errors:
# --> 851     raise exceptions[0]
#     852 raise ExceptionGroup("create_connection failed", exceptions)
#
# File G:\Program Files\anaconda3\Lib\socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_transports\default.py:60, in map_httpcore_exceptions()
#      59 try:
# ---> 60     yield
#      61 except Exception as exc:  # noqa: PIE-786
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_transports\default.py:218, in HTTPTransport.handle_request(self, request)
#     217 with map_httpcore_exceptions():
# --> 218     resp = self._pool.handle_request(req)
#     220 assert isinstance(resp.stream, typing.Iterable)
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py:262, in ConnectionPool.handle_request(self, request)
#     261         self.response_closed(status)
# --> 262     raise exc
#     263 else:
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py:245, in ConnectionPool.handle_request(self, request)
#     244 try:
# --> 245     response = connection.handle_request(request)
#     246 except ConnectionNotAvailable:
#     247     # The ConnectionNotAvailable exception is a special case, that
#     248     # indicates we need to retry the request on a new connection.
#    (...)
#     252     # might end up as an HTTP/2 connection, but which actually ends
#     253     # up as HTTP/1.1.
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_sync\connection.py:92, in HTTPConnection.handle_request(self, request)
#      91         self._connect_failed = True
# ---> 92         raise exc
#      93 elif not self._connection.is_available():
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_sync\connection.py:69, in HTTPConnection.handle_request(self, request)
#      68 try:
# ---> 69     stream = self._connect(request)
#      71     ssl_object = stream.get_extra_info("ssl_object")
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_sync\connection.py:117, in HTTPConnection._connect(self, request)
#     116 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 117     stream = self._network_backend.connect_tcp(**kwargs)
#     118     trace.return_value = stream
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_backends\sync.py:99, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#      94 exc_map: ExceptionMapping = {
#      95     socket.timeout: ConnectTimeout,
#      96     OSError: ConnectError,
#      97 }
# ---> 99 with map_exceptions(exc_map):
#     100     sock = socket.create_connection(
#     101         address,
#     102         timeout,
#     103         source_address=source_address,
#     104     )
#
# File G:\Program Files\anaconda3\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File G:\Program Files\anaconda3\Lib\site-packages\openai\_base_client.py:926, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     925 try:
# --> 926     response = self._client.send(
#     927         request,
#     928         stream=stream or self._should_stream_response_body(request=request),
#     929         **kwargs,
#     930     )
#     931 except httpx.TimeoutException as err:
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_client.py:1002, in Client._send_single_request(self, request)
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_transports\default.py:217, in HTTPTransport.handle_request(self, request)
#     205 req = httpcore.Request(
#     206     method=request.method,
#     207     url=httpcore.URL(
#    (...)
#     215     extensions=request.extensions,
#     216 )
# --> 217 with map_httpcore_exceptions():
#     218     resp = self._pool.handle_request(req)
#
# File G:\Program Files\anaconda3\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File G:\Program Files\anaconda3\Lib\site-packages\httpx\_transports\default.py:77, in map_httpcore_exceptions()
#      76 message = str(exc)
# ---> 77 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 vectorstore = DocArrayInMemorySearch.from_texts(
#       2     ["harrison worked at kensho", "bears like to eat honey"],
#       3     embedding=OpenAIEmbeddings(),
#       4 )
#       5 retriever = vectorstore.as_retriever()
#       7 template = """Answer the question based only on the following context:
#       8 {context}
#       9
#      10 Question: {question}
#      11 """
#
# File G:\Program Files\anaconda3\Lib\site-packages\langchain_community\vectorstores\docarray\in_memory.py:69, in DocArrayInMemorySearch.from_texts(cls, texts, embedding, metadatas, **kwargs)
#      54 """Create an DocArrayInMemorySearch store and insert data.
#      55
#      56 Args:
#    (...)
#      66     DocArrayInMemorySearch Vector Store
#      67 """
#      68 store = cls.from_params(embedding, **kwargs)
# ---> 69 store.add_texts(texts=texts, metadatas=metadatas)
#      70 return store
#
# File G:\Program Files\anaconda3\Lib\site-packages\langchain_community\vectorstores\docarray\base.py:82, in DocArrayIndex.add_texts(self, texts, metadatas, **kwargs)
#      72 """Embed texts and add to the vector store.
#      73
#      74 Args:
#    (...)
#      79     List of ids from adding the texts into the vectorstore.
#      80 """
#      81 ids: List[str] = []
# ---> 82 embeddings = self.embedding.embed_documents(list(texts))
#      83 for i, (t, e) in enumerate(zip(texts, embeddings)):
#      84     m = metadatas[i] if metadatas else {}
#
# File G:\Program Files\anaconda3\Lib\site-packages\langchain_openai\embeddings\base.py:517, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     514 # NOTE: to keep things simple, we assume the list may contain texts longer
#     515 #       than the maximum context and use length-safe embedding function.
#     516 engine = cast(str, self.deployment)
# --> 517 return self._get_len_safe_embeddings(texts, engine=engine)
#
# File G:\Program Files\anaconda3\Lib\site-packages\langchain_openai\embeddings\base.py:333, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     331 batched_embeddings: List[List[float]] = []
#     332 for i in _iter:
# --> 333     response = self.client.create(
#     334         input=tokens[i : i + _chunk_size], **self._invocation_params
#     335     )
#     336     if not isinstance(response, dict):
#     337         response = response.model_dump()
#
# File G:\Program Files\anaconda3\Lib\site-packages\openai\resources\embeddings.py:113, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     107         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     108             base64.b64decode(data), dtype="float32"
#     109         ).tolist()
#     111     return obj
# --> 113 return self._post(
#     114     "/embeddings",
#     115     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     116     options=make_request_options(
#     117         extra_headers=extra_headers,
#     118         extra_query=extra_query,
#     119         extra_body=extra_body,
#     120         timeout=timeout,
#     121         post_parser=parser,
#     122     ),
#     123     cast_to=CreateEmbeddingResponse,
#     124 )
#
# File G:\Program Files\anaconda3\Lib\site-packages\openai\_base_client.py:1208, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1194 def post(
#    1195     self,
#    1196     path: str,
#    (...)
#    1203     stream_cls: type[_StreamT] | None = None,
#    1204 ) -> ResponseT | _StreamT:
#    1205     opts = FinalRequestOptions.construct(
#    1206         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1207     )
# -> 1208     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File G:\Program Files\anaconda3\Lib\site-packages\openai\_base_client.py:897, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888 def request(
#     889     self,
#     890     cast_to: Type[ResponseT],
#    (...)
#     895     stream_cls: type[_StreamT] | None = None,
#     896 ) -> ResponseT | _StreamT:
# --> 897     return self._request(
#     898         cast_to=cast_to,
#     899         options=options,
#     900         stream=stream,
#     901         stream_cls=stream_cls,
#     902         remaining_retries=remaining_retries,
#     903     )
#
# File G:\Program Files\anaconda3\Lib\site-packages\openai\_base_client.py:950, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     947 log.debug("Encountered Exception", exc_info=True)
#     949 if retries > 0:
# --> 950     return self._retry_request(
#     951         options,
#     952         cast_to,
#     953         retries,
#     954         stream=stream,
#     955         stream_cls=stream_cls,
#     956         response_headers=None,
#     957     )
#     959 log.debug("Raising connection error")
#     960 raise APIConnectionError(request=request) from err
#
# File G:\Program Files\anaconda3\Lib\site-packages\openai\_base_client.py:1021, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1017 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1018 # different thread if necessary.
#    1019 time.sleep(timeout)
# -> 1021 return self._request(
#    1022     options=options,
#    1023     cast_to=cast_to,
#    1024     remaining_retries=remaining,
#    1025     stream=stream,
#    1026     stream_cls=stream_cls,
#    1027 )
#
# File G:\Program Files\anaconda3\Lib\site-packages\openai\_base_client.py:950, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     947 log.debug("Encountered Exception", exc_info=True)
#     949 if retries > 0:
# --> 950     return self._retry_request(
#     951         options,
#     952         cast_to,
#     953         retries,
#     954         stream=stream,
#     955         stream_cls=stream_cls,
#     956         response_headers=None,
#     957     )
#     959 log.debug("Raising connection error")
#     960 raise APIConnectionError(request=request) from err
#
# File G:\Program Files\anaconda3\Lib\site-packages\openai\_base_client.py:1021, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1017 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1018 # different thread if necessary.
#    1019 time.sleep(timeout)
# -> 1021 return self._request(
#    1022     options=options,
#    1023     cast_to=cast_to,
#    1024     remaining_retries=remaining,
#    1025     stream=stream,
#    1026     stream_cls=stream_cls,
#    1027 )
#
# File G:\Program Files\anaconda3\Lib\site-packages\openai\_base_client.py:960, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     950         return self._retry_request(
#     951             options,
#     952             cast_to,
#    (...)
#     956             response_headers=None,
#     957         )
#     959     log.debug("Raising connection error")
# --> 960     raise APIConnectionError(request=request) from err
#     962 log.debug(
#     963     'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     964 )
#     966 try:
#
# APIConnectionError: Connection error.

# %%
pip install langchain docarray tiktoken
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple, https://mirrors.aliyun.com/pypi/simple/, https://mirror.baidu.com/pypi/simple
# Requirement already satisfied: langchain in g:\program files\anaconda3\lib\site-packages (0.1.14)
# Collecting docarray
#   Downloading https://mirror.baidu.com/pypi/packages/27/bf/90439e206a5d2df089e3467a703dfa0349f17d73f003ec51367db23bf8de/docarray-0.40.0-py3-none-any.whl (270 kB)
#      ---------------------------------------- 0.0/270.2 kB ? eta -:--:--
#      -------------------------------------  266.2/270.2 kB 8.3 MB/s eta 0:00:01
#      -------------------------------------- 270.2/270.2 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: tiktoken in g:\program files\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: PyYAML>=5.3 in g:\program files\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in g:\program files\anaconda3\lib\site-packages (from langchain) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in g:\program files\anaconda3\lib\site-packages (from langchain) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in g:\program files\anaconda3\lib\site-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in g:\program files\anaconda3\lib\site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.30 in g:\program files\anaconda3\lib\site-packages (from langchain) (0.0.31)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.37 in g:\program files\anaconda3\lib\site-packages (from langchain) (0.1.38)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in g:\program files\anaconda3\lib\site-packages (from langchain) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in g:\program files\anaconda3\lib\site-packages (from langchain) (0.1.31)
# Requirement already satisfied: numpy<2,>=1 in g:\program files\anaconda3\lib\site-packages (from langchain) (1.24.3)
# Requirement already satisfied: pydantic<3,>=1 in g:\program files\anaconda3\lib\site-packages (from langchain) (2.6.4)
# Requirement already satisfied: requests<3,>=2 in g:\program files\anaconda3\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in g:\program files\anaconda3\lib\site-packages (from langchain) (8.2.3)
# Requirement already satisfied: orjson>=3.8.2 in g:\program files\anaconda3\lib\site-packages (from docarray) (3.9.15)
# Requirement already satisfied: rich>=13.1.0 in g:\program files\anaconda3\lib\site-packages (from docarray) (13.7.0)
# Collecting types-requests>=2.28.11.6 (from docarray)
#   Using cached https://mirror.baidu.com/pypi/packages/6d/05/f9ccc1e7c1760367686834637ca41f2c13cb865c5c3e0505d18c9110cd9b/types_requests-2.31.0.20240403-py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-inspect>=0.8.0 in g:\program files\anaconda3\lib\site-packages (from docarray) (0.9.0)
# Requirement already satisfied: regex>=2022.1.18 in g:\program files\anaconda3\lib\site-packages (from tiktoken) (2022.7.9)
# Requirement already satisfied: aiosignal>=1.1.2 in g:\program files\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in g:\program files\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in g:\program files\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in g:\program files\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in g:\program files\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in g:\program files\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.2)
# Requirement already satisfied: jsonpointer>=1.9 in g:\program files\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.1)
# Requirement already satisfied: packaging<24.0,>=23.2 in g:\program files\anaconda3\lib\site-packages (from langchain-core<0.2.0,>=0.1.37->langchain) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in g:\program files\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in g:\program files\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in g:\program files\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in g:\program files\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in g:\program files\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in g:\program files\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in g:\program files\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in g:\program files\anaconda3\lib\site-packages (from rich>=13.1.0->docarray) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in g:\program files\anaconda3\lib\site-packages (from rich>=13.1.0->docarray) (2.15.1)
# Requirement already satisfied: greenlet!=0.4.17 in g:\program files\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in g:\program files\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->docarray) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in g:\program files\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.1.0->docarray) (0.1.0)
# Installing collected packages: types-requests, docarray
# Successfully installed docarray-0.40.0 types-requests-2.31.0.20240403
# Note: you may need to restart the kernel to use updated packages.
